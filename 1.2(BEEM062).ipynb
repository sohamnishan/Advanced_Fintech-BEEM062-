# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import quandl
import time
import json
import requests
from datetime import date

# %%
quandl.ApiConfig.api_key = '-ZLHxSyKy1s2urPTnG44'
features = ['Adj_Close']
McDonalds = quandl.get("EOD/MCD", start_date='2013-09-03', end_date='2017-12-28')

# %%
McDonalds
# Out:
#                Open    High      Low   Close     Volume  Dividend  Split  \
# Date
# 2013-09-03   95.100   95.28   94.120   94.52  3672100.0       0.0    1.0
# 2013-09-04   94.500   95.36   94.340   95.16  2898800.0       0.0    1.0
# 2013-09-05   95.330   96.46   95.080   95.66  4275300.0       0.0    1.0
# 2013-09-06   95.870   96.75   95.250   96.26  4485800.0       0.0    1.0
# 2013-09-09   96.220   96.79   96.210   96.45  3525200.0       0.0    1.0
# ...             ...     ...      ...     ...        ...       ...    ...
# 2017-12-21  172.680  172.75  171.670  171.85  2341676.0       0.0    1.0
# 2017-12-22  171.375  172.04  170.550  171.42  3234143.0       0.0    1.0
# 2017-12-26  171.090  171.64  170.820  171.29  1280227.0       0.0    1.0
# 2017-12-27  171.330  172.74  170.845  172.67  1596817.0       0.0    1.0
# 2017-12-28  173.260  173.55  172.620  173.10  1800068.0       0.0    1.0
#
#               Adj_Open    Adj_High     Adj_Low   Adj_Close  Adj_Volume
# Date
# ...

# %%
int(time.mktime(time.strptime('2021-05-20', '%Y-%m-%d')))
# Out:
# 1621465200

# %%
URL="https://min-api.cryptocompare.com/data/v2/histoday?fsym=BTC&tsym=USD&limit=2000&toTs=1621465200&api_key=aa0888efdbbb911e79e296c6f674d5fc440217860b85af736b9df6853bab8746"

# %%
answer=requests.get(URL)
data=json.loads(answer.text)
data=data['Data']
data=data['Data']
data
# Out:
# [{'time': 1448582400,
#   'high': 363.9,
#   'low': 345.15,
#   'open': 353.74,
#   'volumefrom': 103479.86,
#   'volumeto': 36955394.2,
#   'close': 359.52,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1448668800,
#   'high': 360.08,
#   'low': 350.49,
#   'open': 359.52,
#   'volumefrom': 56171.07,
#   'volumeto': 19988111.49,
#   'close': 355.83,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1448755200,
#   'high': 372.84,
#   'low': 354.55,
#   'open': 355.83,
#   'volumefrom': 67365.88,
#   'volumeto': 24546100.04,
#   'close': 370.84,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1448841600,
#   'high': 382.56,
#   'low': 367.87,
#   'open': 370.84,
#   'volumefrom': 129767.07,
#   'volumeto': 48913368.38,
#   'close': 377.97,
#   'conversionType': 'direct',
#   'conversionSymbol': ''},
#  {'time': 1448928000,
#   'high': 379.02,
#   'low': 353.66,
#   'open': 377.97,
#   'volumefrom': 111904.7,
# ...

# %%
rows=[]
for entries in data:
    epoch=entries['time']
    date=time.strftime('%Y/%m/%d',time.localtime(epoch))
    closing_price=entries['close']
    rows.append((date,closing_price))

# %%
rows
# Out:
# [('2015/11/27', 359.52),
#  ('2015/11/28', 355.83),
#  ('2015/11/29', 370.84),
#  ('2015/11/30', 377.97),
#  ('2015/12/01', 361.8),
#  ('2015/12/02', 359.98),
#  ('2015/12/03', 360.31),
#  ('2015/12/04', 361.67),
#  ('2015/12/05', 386.69),
#  ('2015/12/06', 393.38),
#  ('2015/12/07', 394.28),
#  ('2015/12/08', 410.67),
#  ('2015/12/09', 416),
#  ('2015/12/10', 415.49),
#  ('2015/12/11', 449.83),
#  ('2015/12/12', 432.29),
#  ('2015/12/13', 434.69),
#  ('2015/12/14', 442),
#  ('2015/12/15', 462.65),
#  ('2015/12/16', 453.98),
#  ('2015/12/17', 455.53),
#  ('2015/12/18', 463.18),
#  ('2015/12/19', 461.2),
#  ('2015/12/20', 441.78),
#  ('2015/12/21', 437.59),
#  ('2015/12/22', 437.03),
#  ('2015/12/23', 442.43),
#  ('2015/12/24', 452.98),
#  ('2015/12/25', 454.05),
#  ('2015/12/26', 415.37),
#  ('2015/12/27', 422.39),
#  ('2015/12/28', 421.76),
#  ('2015/12/29', 431.92),
#  ('2015/12/30', 427.15),
#  ('2015/12/31', 429.95),
#  ('2016/01/01', 433.99),
#  ('2016/01/02', 433.72),
# ...

# %%
Bitcoin=pd.DataFrame(rows)
Bitcoin.columns=['date','close price']
Bitcoin['date']=pd.to_datetime(Bitcoin['date'])
Bitcoin.head()
# Out:
#         date  close price
# 0 2015-11-27       359.52
# 1 2015-11-28       355.83
# 2 2015-11-29       370.84
# 3 2015-11-30       377.97
# 4 2015-12-01       361.80

# %%
table=pd.merge(Bitcoin,McDonalds,left_on='date',right_on='Date')
table=table[['date','close price','Adj_Close']]
table=table.set_index(['date'])
table.head()
# Out:
#             close price  Adj_Close
# date
# 2015-11-27       359.52  99.200188
# 2015-11-30       377.97  99.139398
# 2015-12-01       361.80  99.391241
# 2015-12-02       359.98  98.757291
# 2015-12-03       360.31  98.470711

# %%
xt=table['Adj_Close'].values.tolist()
yt=table['close price'].values.tolist()

# %%
xt = (xt - np.mean(xt))/(np.std(xt))
yt = (yt - np.mean(yt))/(np.std(yt))

# %%
plt.plot(xt,yt,'go')
plt.xlabel("McDonalds Adj_close_price")
plt.ylabel("Bitcoin")
# Out:
# Text(0, 0.5, 'Bitcoin')

# %%
beta = ((np.multiply(yt, xt)).mean()-np.mean(xt)*np.mean(yt))/((np.multiply(xt, xt)).mean()-np.mean(xt)*np.mean(xt))
alpha =np.mean(yt)-beta*np.mean(xt)
print("alpha =",alpha, "\nbeta =",beta)
# Out:
# alpha = -3.0380110038079827e-16
# beta = 0.8032058290391377

# %%
yt_hat = alpha + np.multiply(beta,xt)
L = np.sum(np.multiply(yt - yt_hat,yt - yt_hat))
L
# Out:
# 186.65656839991178

# %%
def  cal_cost(alpha,beta,xt,yt):
        n = len(yt)
        predictions = alpha + np.multiply(beta,xt)
        cost = (1/2*n) * np.sum(np.square(predictions-yt))
        return cost
cal_cost(alpha,beta,xt,yt)
# Out:
# 49090.6774891768

# %%
cal_cost(0,beta,xt,yt)
# Out:
# 49090.67748917681

# %%
iterations = 50
alpha = -1

loss_history = np.zeros((iterations,1))
alpha_history = np.zeros((iterations,1))

for i in range(iterations):
    alpha = alpha +1
    
    loss_history[i] = cal_cost(alpha,beta,xt,yt)
    alpha_history[i] = alpha
    
plt.plot(alpha_history,loss_history,'go')

# %%
iterations = 1000
alpha = -1
n = len(yt)

loss_history = np.zeros((iterations,1))
alpha_history = np.zeros((iterations,1))

for i in range(iterations):
    
        
        prediction = alpha + np.multiply(beta,xt)
        residuals = yt-prediction
        residuals_sum = sum(residuals)
        gradient = -(1/n)*0.02*residuals_sum
 
        alpha = alpha - gradient
    
        loss_history[i] = cal_cost(alpha,beta,xt,yt)
        alpha_history[i] = alpha
    
plt.plot(alpha_history,loss_history,'go')

# %%
loss_history[100]
# Out:
# array([49090.67756823])

# %%
iterations = 1000
learningrate = 0.02
beta0 = -1
beta1 = 0
n = len(yt)
index = np.arange(1, iterations+1, 1).reshape((iterations, 1))

loss_history = np.zeros((iterations,1))
beta0_history = np.zeros((iterations,1))
beta1_history = np.zeros((iterations,1))

for i in range(iterations):
       
        prediction = beta0 + np.multiply(beta1,xt)
        residuals = yt-prediction
        residuals_sum = sum(residuals)
        beta0_gradient = -(1/n)*residuals_sum*(learningrate)
        beta0 = beta0 - beta0_gradient
        beta0_history[i] = beta0
    
        residuals_x = np.multiply(residuals,xt)
        residuals_x_sum = sum(residuals_x)
        beta1_gradient = -(1/n)*residuals_x_sum*(learningrate)
        beta1 = beta1 - beta1_gradient
        beta1_history[i] = beta1
    
        loss_history[i] = cal_cost(beta0,beta1,xt,yt)

# %%
plt.plot(beta1_history,loss_history,'go')

# %%
plt.subplot(311)
plt.plot(index, beta0_history,'go')
plt.subplot(312)
plt.plot(index, beta1_history,'go')
plt.subplot(313)
plt.plot(index, loss_history,'go')

# %%
loss_history
# Out:
# array([[267663.62122857],
#        [259008.13265649],
#        [250695.40143187],
#        [242711.85436374],
#        [235044.4557595 ],
#        [227680.68614   ],
#        [220608.52179743],
#        [213816.41516282],
#        [207293.27595094],
#        [201028.45305186],
#        [195011.71713957],
#        [189233.24396942],
#        [183683.5983368 ],
#        [178353.71867124],
#        [173234.90224043],
#        [168318.79094028],
#        [163597.35764761],
#        [159062.89311334],
#        [154707.99337462],
#        [150525.54766556],
#        [146508.72680657],
#        [142650.9720536 ],
#        [138945.98438885],
#        [135387.71423563],
#        [131970.35158047],
#        [128688.31648645],
#        [125536.24998216],
#        [122509.00531144],
#        [119601.63952968],
#        [116809.40543287],
#        [114127.7438063 ],
#        [111552.27598014],
#        [109078.7966799 ],
#        [106703.26715995],
#        [104421.80860899],
# ...

# %%
beta1_history
# Out:
# array([[0.01606412],
#        [0.03180695],
#        [0.04723493],
#        [0.06235435],
#        [0.07717138],
#        [0.09169207],
#        [0.10592234],
#        [0.11986801],
#        [0.13353477],
#        [0.14692819],
#        [0.16005374],
#        [0.17291678],
#        [0.18552256],
#        [0.19787623],
#        [0.20998282],
#        [0.22184728],
#        [0.23347445],
#        [0.24486908],
#        [0.25603581],
#        [0.26697921],
#        [0.27770375],
#        [0.28821379],
#        [0.29851363],
#        [0.30860747],
#        [0.31849944],
#        [0.32819357],
#        [0.33769381],
#        [0.34700405],
#        [0.35612809],
#        [0.36506964],
#        [0.37383237],
#        [0.38241984],
#        [0.39083556],
#        [0.39908296],
#        [0.40716542],
#        [0.41508623],
#        [0.42284862],
#        [0.43045576],
#        [0.43791077],
#        [0.44521667],
#        [0.45237645],
#        [0.45939304],
#        [0.46626929],
# ...

# %%
# Through standard OLS estimation, Alpha and Beta are coming as -3.0380110038079827e-16 and 0.8032058290391377 respectively.
# Through gradient Decent algorithm using a learning rate of 0.02 and 1000 iteration the same estimated values of alpha and beta are found out.
